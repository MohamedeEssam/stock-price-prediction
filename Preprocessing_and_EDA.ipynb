# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Load Data

# %%
appl = pd.read_csv('DataSet/AAPL.csv')
tsla = pd.read_csv('DataSet/TSLA.csv')
amzn = pd.read_csv('DataSet/AMZN.csv')
mfst = pd.read_csv('DataSet/MSFT.csv')
goog = pd.read_csv('DataSet/GOOG.csv')
meta = pd.read_csv('DataSet/META.csv')

# %% [markdown]
# ## Apple

# %%
appl.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2010-01-08  7.510714  7.571429  7.466429  7.570714   6.417541  447610800
# 1  2010-01-11  7.600000  7.607143  7.444643  7.503929   6.360929  462229600
# 2  2010-01-12  7.471071  7.491786  7.372143  7.418571   6.288572  594459600
# 3  2010-01-13  7.423929  7.533214  7.289286  7.523214   6.377276  605892000
# 4  2010-01-14  7.503929  7.516429  7.465000  7.479643   6.340343  432894000

# %%
appl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3522 entries, 0 to 3521
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3522 non-null   object
#  1   Open       3522 non-null   float64
#  2   High       3522 non-null   float64
#  3   Low        3522 non-null   float64
#  4   Close      3522 non-null   float64
#  5   Adj Close  3522 non-null   float64
#  6   Volume     3522 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 192.7+ KB

# %%
# Drop NULL rows
appl.dropna(inplace=True)
# Change Dtype of Columns
appl["Date"] = pd.to_datetime(appl["Date"])
# appl["Volume"] = appl["Volume"].str.replace(',', '')
# appl = appl.astype({"Open": float, "Volume": float})
# Sort the Database by Date
appl = appl.sort_values(by = 'Date', ignore_index = True)
# Drop rows having Date < '2015-01-01'
appl = appl[appl["Date"] >= '2015-01-01'].reset_index(drop = True)

# %%
appl.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           2268  2268.000000  2268.000000  2268.000000
# mean   2019-07-04 16:57:08.571428608    84.132736    85.053268    83.266692
# min              2015-01-02 00:00:00    22.500000    22.917500    22.367500
# 25%              2017-04-03 18:00:00    35.475626    35.692500    35.260001
# 50%              2019-07-06 12:00:00    54.175002    54.890000    53.483750
# 75%              2021-10-04 06:00:00   141.794995   143.437500   139.567501
# max              2024-01-05 00:00:00   198.020004   199.619995   197.000000
# std                              NaN    56.087504    56.717474    55.502900
#
#              Close    Adj Close        Volume
# count  2268.000000  2268.000000  2.268000e+03
# mean     84.201429    82.341671  1.236637e+08
# min      22.584999    20.798660  2.404830e+07
# 25%      35.455625    33.139778  7.813760e+07
# 50%      54.022501    51.760682  1.055960e+08
# 75%     142.005001   140.428787  1.484299e+08
# max     198.110001   198.110001  6.488252e+08
# std      56.139934    56.628940  6.816456e+07

# %%
appl.to_csv("DataSet/pre_processed_appl.csv", index=False)  # Save to a new CSV file

# %% [markdown]
# ## Tsla

# %%
tsla.head()
# Out:
#          Date       Open       High       Low      Close  Adj Close     Volume
# 0  2014-01-08   9.923333  10.246667  9.917333  10.085333  10.085333   92448000
# 1  2014-01-09  10.166667  10.228667  9.790000   9.835333   9.835333   80730000
# 2  2014-01-10   9.897333   9.926667  9.483333   9.714667   9.714667  111691500
# 3  2014-01-13   9.718667   9.800000  9.188000   9.289333   9.289333   94741500
# 4  2014-01-14   9.366667  10.800000  9.111333  10.751333  10.751333  414105000

# %%
tsla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2516 entries, 0 to 2515
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2516 non-null   object
#  1   Open       2516 non-null   float64
#  2   High       2516 non-null   float64
#  3   Low        2516 non-null   float64
#  4   Close      2516 non-null   float64
#  5   Adj Close  2516 non-null   float64
#  6   Volume     2516 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 137.7+ KB

# %%
# Drop NULL rows
tsla.dropna(inplace=True)
# Change Dtype of Columns
tsla["Date"] = pd.to_datetime(tsla["Date"])
# tsla["Volume"] = tsla["Volume"].str.replace(',', '')
# tsla = tsla.astype({"Open": float, "Volume": float})
# Sort the Database by Date
tsla = tsla.sort_values(by = 'Date', ignore_index = True)
# Drop rows having Date < '2015-01-01'
tsla = tsla[tsla["Date"] >= '2015-01-01'].reset_index(drop = True)

# %%
tsla.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           2268  2268.000000  2268.000000  2268.000000
# mean   2019-07-04 16:57:08.571428608   103.161218   105.436150   100.706913
# min              2015-01-02 00:00:00     9.488000    10.331333     9.403333
# 25%              2017-04-03 18:00:00    16.664168    16.922168    16.459000
# 50%              2019-07-06 12:00:00    23.181332    23.509334    22.823667
# 75%              2021-10-04 06:00:00   213.997497   219.069164   207.559998
# max              2024-01-05 00:00:00   411.470001   414.496674   405.666656
# std                              NaN   111.093742   113.568116   108.352768
#
#              Close    Adj Close        Volume
# count  2268.000000  2268.000000  2.268000e+03
# mean    103.129078   103.129078  1.142388e+08
# min       9.578000     9.578000  1.062000e+07
# 25%      16.679834    16.679834  6.629588e+07
# 50%      23.166667    23.166667  9.351800e+07
# 75%     214.672497   214.672497  1.339807e+08
# max     409.970001   409.970001  9.140820e+08
# std     110.989175   110.989175  7.698080e+07

# %%
tsla.to_csv("DataSet/pre_processed_tsla.csv", index=False)  # Save to a new CSV file

# %% [markdown]
# ## Google

# %%
goog.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2010-01-08  14.744733  15.024933  14.672753  14.994298  14.994298
# 1  2010-01-11  15.055070  15.055070  14.795543  14.971633  14.971633
# 2  2010-01-12  14.885456  14.898158  14.645107  14.706875  14.706875
# 3  2010-01-13  14.358431  14.654571  14.293923  14.622441  14.622441
# 4  2010-01-14  14.542989  14.799528  14.515841  14.691184  14.691184
#
#       Volume
# 0  189680313
# 1  289597429
# 2  194859654
# 3  260838034
# 4  170239717

# %%
goog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3522 entries, 0 to 3521
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3522 non-null   object
#  1   Open       3522 non-null   float64
#  2   High       3522 non-null   float64
#  3   Low        3522 non-null   float64
#  4   Close      3522 non-null   float64
#  5   Adj Close  3522 non-null   float64
#  6   Volume     3522 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 192.7+ KB

# %%
# Drop NULL rows
goog.dropna(inplace=True)
# Change Dtype of Columns
goog["Date"] = pd.to_datetime(goog["Date"])
# for col in ["Open", "High", "Low", "Close", "Adj. Close", "Volume"]:
#   goog[col] = goog[col].str.replace(',', '')

# goog = goog.astype({"Open": float, "High": float, "Low": float, "Close": float, "Adj. Close": float, "Volume": float})
# Sort the Database by Date
goog = goog.sort_values(by = 'Date', ignore_index = True)
# Drop rows having Date < '2015-01-01'
goog = goog[goog["Date"] >= '2015-01-01'].reset_index(drop = True)

# %%
goog.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           2268  2268.000000  2268.000000  2268.000000
# mean   2019-07-04 16:57:08.571428608    73.678967    74.476536    72.943232
# min              2015-01-02 00:00:00    24.664783    24.730902    24.311253
# 25%              2017-04-03 18:00:00    41.793875    42.099373    41.576125
# 50%              2019-07-06 12:00:00    59.813999    60.277251    59.361750
# 75%              2021-10-04 06:00:00   104.917000   106.186000   103.664253
# max              2024-01-05 00:00:00   151.863495   152.100006   149.887497
# std                              NaN    36.622783    37.062281    36.225441
#
#              Close    Adj Close        Volume
# count  2268.000000  2268.000000  2.268000e+03
# mean     73.726504    73.726504  3.198350e+07
# min      24.560070    24.560070  6.936000e+06
# 25%      41.854126    41.854126  2.249000e+07
# 50%      59.862999    59.862999  2.813995e+07
# 75%     105.029247   105.029247  3.658700e+07
# max     150.709000   150.709000  2.232980e+08
# std      36.640556    36.640556  1.547777e+07

# %%
goog.to_csv('DataSet/pre_processed_goog.csv', index=False)

# %% [markdown]
# ## Microsoft

# %%
mfst.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2010-01-08  30.280001  30.879999  30.240000  30.660000  23.254961  51197400
# 1  2010-01-11  30.709999  30.760000  30.120001  30.270000  22.959160  68754700
# 2  2010-01-12  30.150000  30.400000  29.910000  30.070000  22.807455  65912100
# 3  2010-01-13  30.260000  30.520000  30.010000  30.350000  23.019827  51863500
# 4  2010-01-14  30.309999  31.100000  30.260000  30.959999  23.482506  63228100

# %%
mfst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3522 entries, 0 to 3521
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3522 non-null   object
#  1   Open       3522 non-null   float64
#  2   High       3522 non-null   float64
#  3   Low        3522 non-null   float64
#  4   Close      3522 non-null   float64
#  5   Adj Close  3522 non-null   float64
#  6   Volume     3522 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 192.7+ KB

# %%
# Drop NULL rows
mfst.dropna(inplace = True)
# Change Dtype of Columns
mfst["Date"] = pd.to_datetime(mfst["Date"])
# mfst["Open"] = mfst["Open"].str.replace(',', '')
# mfst["Volume"] = mfst["Volume"].str.replace(',', '')
# mfst = mfst.astype({"Open": float, "Volume": float})
# Sort the Database by Date
mfst = mfst.sort_values(by = 'Date', ignore_index = True)
# Drop rows having Date < '2015-01-01'
mfst = mfst[mfst["Date"] >= '2015-01-01'].reset_index(drop = True)

# %%
mfst.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           2268  2268.000000  2268.000000  2268.000000
# mean   2019-07-04 16:57:08.571428608   162.121517   163.744899   160.450807
# min              2015-01-02 00:00:00    40.340000    40.740002    39.720001
# 25%              2017-04-03 18:00:00    65.412498    65.750000    64.995001
# 50%              2019-07-06 12:00:00   135.275002   136.415001   133.590004
# 75%              2021-10-04 06:00:00   251.102501   254.154998   249.062500
# max              2024-01-05 00:00:00   383.760010   384.299988   378.160004
# std                              NaN   100.521815   101.558168    99.446781
#
#              Close    Adj Close        Volume
# count  2268.000000  2268.000000  2.268000e+03
# mean    162.176773   157.195457  2.978948e+07
# min      40.290001    34.950619  7.425600e+06
# 25%      65.477502    60.121465  2.146560e+07
# 50%     135.434998   129.875328  2.649815e+07
# 75%     251.922497   248.025253  3.381492e+07
# max     382.700012   382.700012  1.691640e+08
# std     100.548554   101.447766  1.355226e+07

# %%
mfst.to_csv('DataSet/pre_processed_mfst.csv', index=False)

# %% [markdown]
# ## Amazon

# %%
amzn.head()
# Out:
#          Date    Open    High     Low   Close  Adj Close     Volume
# 0  2010-01-08  6.5280  6.6840  6.4515  6.6760     6.6760  196610000
# 1  2010-01-11  6.6310  6.6400  6.4605  6.5155     6.5155  175588000
# 2  2010-01-12  6.4495  6.4910  6.3275  6.3675     6.3675  181926000
# 3  2010-01-13  6.3950  6.4855  6.2875  6.4555     6.4555  214464000
# 4  2010-01-14  6.4570  6.5190  6.3200  6.3675     6.3675  195498000

# %%
amzn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3522 entries, 0 to 3521
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3522 non-null   object
#  1   Open       3522 non-null   float64
#  2   High       3522 non-null   float64
#  3   Low        3522 non-null   float64
#  4   Close      3522 non-null   float64
#  5   Adj Close  3522 non-null   float64
#  6   Volume     3522 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 192.7+ KB

# %%
# Drop NULL rows
amzn.dropna(inplace = True)
# Change Dtype of Columns
amzn["Date"] = pd.to_datetime(amzn["Date"])

# for col in ["Open", "High", "Low", "Close", "Adj. Close", "Volume"]:
    # amzn[col] = amzn[col].str.replace(',', '')

# amzn = amzn.astype({"Open": float, "High": float, "Low": float, "Close": float, "Adj. Close": float, "Volume": float})
# Sort the Database by Date
amzn = amzn.sort_values(by = 'Date', ignore_index = True)
# Drop rows having Date < '2015-01-01'
amzn = amzn[amzn["Date"] >= '2015-01-01'].reset_index(drop = True)

# %%
amzn.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           2268  2268.000000  2268.000000  2268.000000
# mean   2019-07-04 16:57:08.571428608    92.078605    93.147690    90.911478
# min              2015-01-02 00:00:00    14.314000    14.539500    14.262500
# 25%              2017-04-03 18:00:00    44.393752    44.730001    44.259375
# 50%              2019-07-06 12:00:00    90.820999    91.503750    89.887753
# 75%              2021-10-04 06:00:00   133.750003   135.027503   132.170006
# max              2024-01-05 00:00:00   187.199997   188.654007   184.839493
# std                              NaN    48.710675    49.316602    48.049064
#
#              Close    Adj Close        Volume
# count  2268.000000  2268.000000  2.268000e+03
# mean     92.047721    92.047721  8.000507e+07
# min      14.347500    14.347500  1.762600e+07
# 25%      44.513375    44.513375  5.386500e+07
# 50%      90.719753    90.719753  6.858700e+07
# 75%     133.574997   133.574997  9.332150e+07
# max     186.570496   186.570496  4.771220e+08
# std      48.666657    48.666657  4.062164e+07

# %%
amzn.to_csv('DataSet/pre_processed_amzn.csv', index=False)

# %% [markdown]
# ## META

# %%
meta.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2014-01-08  57.599998  58.410000  57.230000  58.230000  58.230000  56682400
# 1  2014-01-09  58.650002  58.959999  56.650002  57.220001  57.220001  92253300
# 2  2014-01-10  57.130001  58.299999  57.060001  57.939999  57.939999  42449500
# 3  2014-01-13  57.910000  58.250000  55.380001  55.910000  55.910000  63010900
# 4  2014-01-14  56.459999  57.779999  56.099998  57.740002  57.740002  37503600

# %%
meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2516 entries, 0 to 2515
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2516 non-null   object
#  1   Open       2516 non-null   float64
#  2   High       2516 non-null   float64
#  3   Low        2516 non-null   float64
#  4   Close      2516 non-null   float64
#  5   Adj Close  2516 non-null   float64
#  6   Volume     2516 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 137.7+ KB

# %%
# Drop NULL rows
meta.dropna(inplace = True)
# Change Dtype of Columns
meta["Date"] = pd.to_datetime(meta["Date"])


# Sort the Database by Date
meta = meta.sort_values(by = 'Date', ignore_index = True)
# Drop rows having Date < '2015-01-01'
meta = meta[meta["Date"] >= '2015-01-01'].reset_index(drop = True)

# %%
meta.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           2268  2268.000000  2268.000000  2268.000000
# mean   2019-07-04 16:57:08.571428608   190.474705   192.927870   188.121146
# min              2015-01-02 00:00:00    74.040001    74.830002    72.000000
# 25%              2017-04-03 18:00:00   130.145000   131.797501   128.590004
# 50%              2019-07-06 12:00:00   177.230004   179.004997   175.540001
# 75%              2021-10-04 06:00:00   237.722496   240.407494   232.742504
# max              2024-01-05 00:00:00   381.679993   384.329987   378.809998
# std                              NaN    76.571227    77.592897    75.607597
#
#              Close    Adj Close        Volume
# count  2268.000000  2268.000000  2.268000e+03
# mean    190.579625   190.579625  2.377724e+07
# min      74.050003    74.050003  5.467500e+06
# 25%     130.102501   130.102501  1.520228e+07
# 50%     177.455002   177.455002  2.001535e+07
# 75%     237.204998   237.204998  2.729982e+07
# max     382.179993   382.179993  2.323166e+08
# std      76.605608    76.605608  1.515055e+07

# %%
meta.to_csv('DataSet/pre_processed_meta.csv', index=False)

# %% [markdown]
# # EDA

# %%
Companies = [appl, tsla, goog, mfst, amzn, meta]
Companies_Title = ["Apple", "Tesla", "Google", "Microsoft", "Amazon", "Meta"]

# %%
# Lets view historical view of the closing prices

plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
    plt.subplot(3, 2, index+1)
    plt.plot(company["Date"], company["Adj Close"])
    plt.title(Companies_Title[index])
    plt.ylabel('Adj Close')

# %% [markdown]
# We can that Tesal have growth in the 2020-2021 period and Meta is down alot in the 2022-2023 period.
#
#
# For the rest of the Companies, we can see that COVID-19 is the primary factor affecting the 2020-2021 period.

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
    plt.subplot(3, 2, index+1)
    plt.plot(company['Date'], company['Volume'])
    plt.title(Companies_Title[index])
    plt.ylabel("Volume")

# %% [markdown]
# We have seen the visualization of closing price and volume traded every day.
# * let's go ahead and calculate the moving average of the stock.

# %% [markdown]
# ### What was the moving average of the various stocks ?

# %%
Move_Avg_Day = [10, 20, 50]
for Move_Avg in Move_Avg_Day:
    for company in Companies:
        col_name = f'Moving Average for {Move_Avg} days'
        company[col_name] = company["Adj Close"].rolling(Move_Avg).mean()

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
    plt.subplot(3, 2, index+1)
    plt.plot(company['Date'], company['Adj Close'])
    plt.plot(company['Date'], company['Moving Average for 10 days'])
    plt.plot(company['Date'], company['Moving Average for 20 days'])
    plt.plot(company['Date'], company['Moving Average for 50 days'])
    plt.title(Companies_Title[index])
    plt.legend(("Adj Close", "Moving Average for 10 days", "Moving Average for 20 days", "Moving Average for 50 days"))

# %% [markdown]
# ### What was the daily return of the stock on average ?
# - Now that we've done some baseline analysis, let's go ahead and dive a little deeper.
# - We're now going to analyze the risk of the stock.
# - In order to do so we'll need to take a closer look at the daily changes of the stock, and not just its absolute value.

# %%
# pct_change() function calculates the percentage change between the current and a prior element.
# This function by default calculates the percentage change from the immediately previous row. 
for company in Companies:
    company["Daily Return"] = company['Adj Close'].pct_change()

# %%
company['Daily Return']
# Out:
# 0            NaN
# 1      -0.016061
# 2      -0.013473
# 3       0.000000
# 4       0.026658
#           ...
# 2263   -0.012168
# 2264   -0.021669
# 2265   -0.005256
# 2266    0.007693
# 2267    0.013915
# Name: Daily Return, Length: 2268, dtype: float64

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  plt.plot(company["Date"], company["Daily Return"])
  plt.title(Companies_Title[index])
  plt.ylabel('Daily Return')

# %% [markdown]
# Now, let's get an overall at the average daily return using a histogram.

# %%
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(20, 15))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  sns.distplot(company["Daily Return"].dropna(), color='green')
  plt.title(Companies_Title[index])

# %%
print("Kurtosis Value")
for index, company in enumerate(Companies):
  print(f'{Companies_Title[index]}: {company["Daily Return"].kurtosis()}')
# Out:
# Kurtosis Value
# Apple: 5.2455021261396695
# Tesla: 4.33612514016532
# Google: 6.843577475683846
# Microsoft: 7.727732570444417
# Amazon: 6.247373054444109
# Meta: 21.670195660550462

# %% [markdown]
# The above graph and the positive kurtosis value indicate that getting extreme daily return values is rare.

# %% [markdown]
# ### What was the correlation between diffrent stocks closing price ?

# %%
# Companies_return contain closing price of all the companies
Companies_returns = pd.DataFrame()
Companies_returns["AAPL"] = appl["Adj Close"]
Companies_returns["TSLA"] = tsla["Adj Close"]
Companies_returns["GOOG"] = goog["Adj Close"]
Companies_returns["MSFT"] = mfst["Adj Close"]
Companies_returns["AMZN"] = amzn["Adj Close"]
Companies_returns["META"] = meta["Adj Close"]

Companies_returns.head()
# Out:
#         AAPL       TSLA       GOOG       MSFT     AMZN       META
# 0  24.466450  14.620667  26.168653  40.452736  15.4260  78.449997
# 1  23.777184  14.006000  25.623152  40.080742  15.1095  77.190002
# 2  23.779427  14.085333  25.029282  39.492462  14.7645  76.150002
# 3  24.112869  14.063333  24.986401  39.994228  14.9210  76.150002
# 4  25.039341  14.041333  25.065184  41.170792  15.0230  78.180000

# %%
# Companies_Daily_returns contains percentage daily returns of all the companies
Companies_Daily_returns = Companies_returns.pct_change()
Companies_Daily_returns.head()
# Out:
#        AAPL      TSLA      GOOG      MSFT      AMZN      META
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1 -0.028172 -0.042041 -0.020846 -0.009196 -0.020517 -0.016061
# 2  0.000094  0.005664 -0.023177 -0.014677 -0.022833 -0.013473
# 3  0.014022 -0.001562 -0.001713  0.012705  0.010600  0.000000
# 4  0.038422 -0.001564  0.003153  0.029418  0.006836  0.026658

# %% [markdown]
# Now, let's do a correlation plot, to get actual numerical values for the correlation between the stocks closing price

# %%
sns.heatmap(Companies_returns.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# Finally, let's do a correlation plot, to get actual numerical values for the correlation between the stocks daily returns.

# %%
sns.heatmap(Companies_Daily_returns.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# From the above plot, we can see that Microsoft and Google had the strongest correlation in stocks daily returns.

# %% [markdown]
# ### How much value do we put at risk by investing in a paticular stock ?

# %% [markdown]
# There are many ways we can quantify risk, one of the most basic ways using the information we've gathered on daily percentage returns is by comparing the expected return with the standard deviation of the daily returns.

# %%
Returns = Companies_Daily_returns.dropna()

plt.figure(figsize=(20, 5))
plt.scatter(Returns.mean(), Returns.std())
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(Companies_Title, Returns.mean(), Returns.std()):
    plt.annotate(label, xy = (x, y), xytext = (10, 0), textcoords = 'offset points')

# %% [markdown]
# From the above graph, we can see that Tesla has the highest expected returns and the highest risk factor. Google has the lowest expected returns and the lowest risk factor.
